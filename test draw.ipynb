# %% [markdown]
# # `draw` method
#
# Se verifica su funcionamiento.

# %%
import proximitygraphs as pg
config = {
            'point_generator': {
                'name': 'normal_dist',
                'params': {'n': 500, 'dims': 2}
            },
            'transformations': [
                {
                    'name': 'perturb',
                    'params': {'radius': 0.25}
                }
            ],
            'graph': {
                'type': 'ProximityGraph',
                'name': 'Beta_Skeleton',
                'params': {'beta': 1.5}
            }
        }

points, graph = pg.Experiment(config).run()

# %% [markdown]
# # kwargs

# %%
graph.draw(
    v_kwargs={"marker": "x", "zorder": 3},
    e_kwargs={"linestyle": "--"},
    fig_kwargs={"facecolor": "none"},
    title_kwargs={"loc": "left"},
)
# Out:
# (<Figure size 600x600 with 1 Axes>, <Axes: title={'left': 'β-Skeleton'}>)

# %% [markdown]
# # Demo

# %%
vcolor = '#051650'
ecolor = '#0A2472'

# %%
from proximitygraphs import SetPoints

uniform_sphere = SetPoints.uniform_sphere(n=200, dims = 2, seed=0)

# %%
graph.draw(figsize=(6, 6), v_size=2, e_size=1, v_alpha=1, e_alpha=1, v_color=vcolor, e_color=ecolor, title=True, details=True, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'β-Skeleton\nβ=1.5, closed=False, type=lune'}>)

# %%
from proximitygraphs import Alpha_Hull

H = Alpha_Hull(uniform_sphere, alpha=-5, n_points_per_arc=50)
H.draw(title=True, details=True, figsize=(6,6), v_size=2, e_size=1, v_color=vcolor, e_color=ecolor, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Alpha-Hull\nalpha=-5'}>)

# %%
from proximitygraphs import Alpha_Shape

H = Alpha_Shape(uniform_sphere, alpha=-5)
H.draw(title=True, details=True, figsize=(6,6), v_size=2, e_size=1, v_color=vcolor, e_color=ecolor, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Alpha-Shape\nalpha=-5'}>)

# %%
from proximitygraphs import DelaunayG

H = DelaunayG(uniform_sphere)
H.draw(title=True, details=True, figsize=(6,6), v_size=3, e_size=1, v_color=vcolor, e_color=ecolor, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Delaunay Triangulation'}>)

# %%
from proximitygraphs import Beta_Skeleton

H = Beta_Skeleton(uniform_sphere, beta=2)
H.draw(title=True, details=True, figsize=(6,6), v_size=3, e_size=1, v_color=vcolor, e_color=ecolor, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'β-Skeleton\nβ=2, closed=False, type=lune'}>)

# %%
from proximitygraphs import Convex_Hull

H = Convex_Hull(uniform_sphere)
H.draw(title=True, details=True, figsize=(6,6), v_size=3, e_size=1, v_color=vcolor, e_color=ecolor, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>, <Axes: title={'center': 'Convex Hull'}>)

# %%
from proximitygraphs import MST

H = MST(uniform_sphere)
H.draw(title=True, details=True, figsize=(6,6), v_size=3, e_size=1, v_color=vcolor, e_color=ecolor, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Minimum Spanning Tree'}>)

# %%
from proximitygraphs import Stepping_Stone

H = Stepping_Stone(uniform_sphere, d=3, k=3)
H.draw(title=True, details=True, figsize=(6,6), v_size=3, e_size=1, v_color=vcolor, e_color=ecolor, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Stepping Stone Graph\nd=3, k=3, closed=False'}>)

# %%
from proximitygraphs import NNG

H = NNG(uniform_sphere, k=2)
H.draw(title=True, details=True, figsize=(6,6), v_size=3, e_size=1, v_color=vcolor, e_color=ecolor, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Nearest Neighbor Graph\nk=2'}>)

# %%
from proximitygraphs import GG

H = GG(uniform_sphere)
H.draw(title=True, details=True, figsize=(6,6), v_size=3, e_size=1, v_color=vcolor, e_color=ecolor, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Gabriel Graph\nclosed=True'}>)

# %%
from proximitygraphs import Elliptic_GabrielG

H = Elliptic_GabrielG(uniform_sphere)
H.draw(title=True, details=True, figsize=(6,6), v_size=3, e_size=1, v_color=vcolor, e_color=ecolor, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Elliptic Gabriel Graph\nα=1.5'}>)

# %%
from proximitygraphs import Gamma_Graph

H = Gamma_Graph(uniform_sphere)
H.draw(title=True, details=True, figsize=(6,6), v_size=3, e_size=1, v_color=vcolor, e_color=ecolor, fontsize=10)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'γ-Neighborhood Graph\nγ0=0.0, γ1=0.0, closed=False'}>)
